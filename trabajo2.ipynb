# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
#Import required libraries
from bs4 import BeautifulSoup
from datetime import datetime
import requests
import time

# %%
# Make a GET request
req = requests.get('http://www.ilga.gov/senate/default.asp')
#Read the content of the server's response
src = req.text
# View some output
print (src[:1000])
# Out:
# <html lang="en">
# <!-- Trigger/Open The Modal -->
# <div style="position: fixed; z-index: 999; top: 5; left: 600; background-color: navy; display: block">
# <button id="myBtn" style="color: white; background-color: navy; display: block">Translate Website</button></div>
# <!-- The Modal -->
# <div id="myModal" class="modal" style="display: none">
#   <!-- Modal content -->
#   <div class="modal-content">
#       <div class="modal-header"><h3>
#     <span class="close">&times;</span></h3></div>
#     <p>The Illinois General Assembly offers the Google Translate service for visitor convenience. In no way should it be considered accurate as to the translation of any content herein.</p>
#     <p>Visitors of the Illinois General Assembly website are encouraged to use other translation services available on the internet.</p>
#     <p>The English language version is always the official and authoritative version of this website.</p>
# ...

# %%
soup = BeautifulSoup(src, 'html.parser')

# %%
a_tags = soup.find_all('a')[:10]

# %%
data = []
for tag in a_tags:
    data.append({
        'Tag': tag.name,
        'Text': tag.get_text(strip=True),
        'Href': tag.get('href'),
        'Class': ' '.join(tag.get('class')) if tag.get('class') else None,
        'ID': tag.get('id')
    })

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#   Tag                Text                            Href           Class  \
# 0   a           Translate    https://translate.google.com  goog-logo-link
# 1   a                                        /default.asp            None
# 2   a                Home                               /        mainmenu
# 3   a  Legislation & Laws                   /legislation/        mainmenu
# 4   a              Senate                        /senate/        mainmenu
# 5   a               House                         /house/        mainmenu
# 6   a      My Legislation                 /mylegislation/        mainmenu
# 7   a            Site Map                    /sitemap.asp        mainmenu
# 8   a             Members             /senate/default.asp        sidemenu
# 9   a          Committees  /senate/committees/default.asp        sidemenu
#
#      ID
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None

# %%
df.isnull().sum()
# Out:
# Tag       0
# Text      0
# Href      0
# Class     1
# ID       10
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tag     10 non-null     object
#  1   Text    10 non-null     object
#  2   Href    10 non-null     object
#  3   Class   9 non-null      object
#  4   ID      0 non-null      object
# dtypes: object(5)
# memory usage: 528.0+ bytes

# %%
df.isnull().sum()
# Out:
# Tag       0
# Text      0
# Href      0
# Class     1
# ID       10
# dtype: int64

# %%
df.dtypes
# Out:
# Tag      object
# Text     object
# Href     object
# Class    object
# ID       object
# dtype: object

# %%
print("Valores nulos por columna:")
print(df.isnull().sum())
print("\nInformación del DataFrame:")
df.info()
print("\nConsistencia de tipos en cada columna:")
for column in df.columns:
    unique_types = df[column].apply(type).unique()
    print(f"Columna '{column}': {unique_types}")
    if len(unique_types) == 1:
        print(f"Todos los valores en '{column}' son del tipo {unique_types[0]}")
    else:
        print(f"La columna '{column}' tiene tipos de datos inconsistentes")
# Out:
# Valores nulos por columna:
# Tag       0
# Text      0
# Href      0
# Class     1
# ID       10
# dtype: int64
#
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tag     10 non-null     object
#  1   Text    10 non-null     object
#  2   Href    10 non-null     object
#  3   Class   9 non-null      object
#  4   ID      0 non-null      object
# dtypes: object(5)
# memory usage: 528.0+ bytes
#
# Consistencia de tipos en cada columna:
# Columna 'Tag': [<class 'str'>]
# Todos los valores en 'Tag' son del tipo <class 'str'>
# Columna 'Text': [<class 'str'>]
# Todos los valores en 'Text' son del tipo <class 'str'>
# Columna 'Href': [<class 'str'>]
# Todos los valores en 'Href' son del tipo <class 'str'>
# Columna 'Class': [<class 'str'> <class 'NoneType'>]
# La columna 'Class' tiene tipos de datos inconsistentes
# ...

# %%
data = []
for tag in a_tags:
    data.append({
        'Tag': tag.name,
        'Text': tag.get_text(strip=True),
        'Href': tag.get('href'),
        'Class': ' '.join(tag.get('class')) if tag.get('class') else "No disponible",
        'div id': tag.get('id') if tag.get('id') else "no disponible"
        
    })
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#   Tag                Text                            Href           Class  \
# 0   a           Translate    https://translate.google.com  goog-logo-link
# 1   a                                        /default.asp   No disponible
# 2   a                Home                               /        mainmenu
# 3   a  Legislation & Laws                   /legislation/        mainmenu
# 4   a              Senate                        /senate/        mainmenu
# 5   a               House                         /house/        mainmenu
# 6   a      My Legislation                 /mylegislation/        mainmenu
# 7   a            Site Map                    /sitemap.asp        mainmenu
# 8   a             Members             /senate/default.asp        sidemenu
# 9   a          Committees  /senate/committees/default.asp        sidemenu
#
#           div id
# 0  no disponible
# 1  no disponible
# 2  no disponible
# 3  no disponible
# 4  no disponible
# 5  no disponible
# 6  no disponible
# ...

# %%
print("Valores nulos por columna:")
print(df.isnull().sum())
print("\nInformación del DataFrame:")
df.info()
print("\nConsistencia de tipos en cada columna:")
for column in df.columns:
    unique_types = df[column].apply(type).unique()
    print(f"Columna '{column}': {unique_types}")
    if len(unique_types) == 1:
        print(f"Todos los valores en '{column}' son del tipo {unique_types[0]}")
    else:
        print(f"La columna '{column}' tiene tipos de datos inconsistentes")
# Out:
# Valores nulos por columna:
# Tag       0
# Text      0
# Href      0
# Class     0
# div id    0
# dtype: int64
#
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tag     10 non-null     object
#  1   Text    10 non-null     object
#  2   Href    10 non-null     object
#  3   Class   10 non-null     object
#  4   div id  10 non-null     object
# dtypes: object(5)
# memory usage: 528.0+ bytes
#
# Consistencia de tipos en cada columna:
# Columna 'Tag': [<class 'str'>]
# Todos los valores en 'Tag' son del tipo <class 'str'>
# Columna 'Text': [<class 'str'>]
# Todos los valores en 'Text' son del tipo <class 'str'>
# Columna 'Href': [<class 'str'>]
# Todos los valores en 'Href' son del tipo <class 'str'>
# Columna 'Class': [<class 'str'>]
# Todos los valores en 'Class' son del tipo <class 'str'>
# ...

# %%
df.fillna("No disponible", inplace=True)
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#   Tag                Text                            Href           Class  \
# 0   a           Translate    https://translate.google.com  goog-logo-link
# 1   a                                        /default.asp   No disponible
# 2   a                Home                               /        mainmenu
# 3   a  Legislation & Laws                   /legislation/        mainmenu
# 4   a              Senate                        /senate/        mainmenu
# 5   a               House                         /house/        mainmenu
# 6   a      My Legislation                 /mylegislation/        mainmenu
# 7   a            Site Map                    /sitemap.asp        mainmenu
# 8   a             Members             /senate/default.asp        sidemenu
# 9   a          Committees  /senate/committees/default.asp        sidemenu
#
#           div id
# 0  no disponible
# 1  no disponible
# 2  no disponible
# 3  no disponible
# 4  no disponible
# 5  no disponible
# 6  no disponible
# ...

# %%
print(df.head())
# Out:
#   Tag                Text                          Href           Class  \
# 0   a           Translate  https://translate.google.com  goog-logo-link
# 1   a                                      /default.asp   No disponible
# 2   a                Home                             /        mainmenu
# 3   a  Legislation & Laws                 /legislation/        mainmenu
# 4   a              Senate                      /senate/        mainmenu
#
#           div id
# 0  no disponible
# 1  no disponible
# 2  no disponible
# 3  no disponible
# 4  no disponible

# %%
df = pd.DataFrame(data)
df
# Out:
#   Tag                Text                            Href           Class  \
# 0   a           Translate    https://translate.google.com  goog-logo-link
# 1   a                                        /default.asp   No disponible
# 2   a                Home                               /        mainmenu
# 3   a  Legislation & Laws                   /legislation/        mainmenu
# 4   a              Senate                        /senate/        mainmenu
# 5   a               House                         /house/        mainmenu
# 6   a      My Legislation                 /mylegislation/        mainmenu
# 7   a            Site Map                    /sitemap.asp        mainmenu
# 8   a             Members             /senate/default.asp        sidemenu
# 9   a          Committees  /senate/committees/default.asp        sidemenu
#
#           div id
# 0  no disponible
# 1  no disponible
# 2  no disponible
# 3  no disponible
# 4  no disponible
# 5  no disponible
# 6  no disponible
# ...

# %%
data = []
for tag in a_tags:
    data.append({
        'Tag': tag.name,
        'Text': tag.get_text(strip=True)or "No disponible",
        'Href': tag.get('href'),
        'Class': ' '.join(tag.get('class')) if tag.get('class') else "No disponible",
        'div id': tag.get('id') if tag.get('id') else "no disponible"
        
    })
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#   Tag                Text                            Href           Class  \
# 0   a           Translate    https://translate.google.com  goog-logo-link
# 1   a       No disponible                    /default.asp   No disponible
# 2   a                Home                               /        mainmenu
# 3   a  Legislation & Laws                   /legislation/        mainmenu
# 4   a              Senate                        /senate/        mainmenu
# 5   a               House                         /house/        mainmenu
# 6   a      My Legislation                 /mylegislation/        mainmenu
# 7   a            Site Map                    /sitemap.asp        mainmenu
# 8   a             Members             /senate/default.asp        sidemenu
# 9   a          Committees  /senate/committees/default.asp        sidemenu
#
#           div id
# 0  no disponible
# 1  no disponible
# 2  no disponible
# 3  no disponible
# 4  no disponible
# 5  no disponible
# 6  no disponible
# ...

# %%
print("Valores nulos por columna:")
print(df.isnull().sum())
print("\nInformación del DataFrame:")
df.info()
print("\nConsistencia de tipos en cada columna:")
for column in df.columns:
    unique_types = df[column].apply(type).unique()
    print(f"Columna '{column}': {unique_types}")
    if len(unique_types) == 1:
        print(f"Todos los valores en '{column}' son del tipo {unique_types[0]}")
    else:
        print(f"La columna '{column}' tiene tipos de datos inconsistentes")
# Out:
# Valores nulos por columna:
# Tag       0
# Text      0
# Href      0
# Class     0
# div id    0
# dtype: int64
#
# Información del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tag     10 non-null     object
#  1   Text    10 non-null     object
#  2   Href    10 non-null     object
#  3   Class   10 non-null     object
#  4   div id  10 non-null     object
# dtypes: object(5)
# memory usage: 528.0+ bytes
#
# Consistencia de tipos en cada columna:
# Columna 'Tag': [<class 'str'>]
# Todos los valores en 'Tag' son del tipo <class 'str'>
# Columna 'Text': [<class 'str'>]
# Todos los valores en 'Text' son del tipo <class 'str'>
# Columna 'Href': [<class 'str'>]
# Todos los valores en 'Href' son del tipo <class 'str'>
# Columna 'Class': [<class 'str'>]
# Todos los valores en 'Class' son del tipo <class 'str'>
# ...

# %%
df.dtypes
# Out:
# Tag       object
# Text      object
# Href      object
# Class     object
# div id    object
# dtype: object

# %%
df
# Out:
#   Tag                Text                            Href           Class  \
# 0   a           Translate    https://translate.google.com  goog-logo-link
# 1   a       No disponible                    /default.asp   No disponible
# 2   a                Home                               /        mainmenu
# 3   a  Legislation & Laws                   /legislation/        mainmenu
# 4   a              Senate                        /senate/        mainmenu
# 5   a               House                         /house/        mainmenu
# 6   a      My Legislation                 /mylegislation/        mainmenu
# 7   a            Site Map                    /sitemap.asp        mainmenu
# 8   a             Members             /senate/default.asp        sidemenu
# 9   a          Committees  /senate/committees/default.asp        sidemenu
#
#           div id
# 0  no disponible
# 1  no disponible
# 2  no disponible
# 3  no disponible
# 4  no disponible
# 5  no disponible
# 6  no disponible
# ...

# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import required libraries
from bs4 import BeautifulSoup
from datetime import datetime
import requests
import time

# %%
# Make a GET request
req = requests.get('http://www.ilga.gov/senate/default.asp')
#Read the content of the server's response
src = req.text
# View some output
print (src[:1000])
# Out:
# <html lang="en">
# <!-- Trigger/Open The Modal -->
# <div style="position: fixed; z-index: 999; top: 5; left: 600; background-color: navy; display: block">
# <button id="myBtn" style="color: white; background-color: navy; display: block">Translate Website</button></div>
# <!-- The Modal -->
# <div id="myModal" class="modal" style="display: none">
#   <!-- Modal content -->
#   <div class="modal-content">
#       <div class="modal-header"><h3>
#     <span class="close">&times;</span></h3></div>
#     <p>The Illinois General Assembly offers the Google Translate service for visitor convenience. In no way should it be considered accurate as to the translation of any content herein.</p>
#     <p>Visitors of the Illinois General Assembly website are encouraged to use other translation services available on the internet.</p>
#     <p>The English language version is always the official and authoritative version of this website.</p>
# ...

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
soup = BeautifulSoup(src, 'html.parser')
a_tags = soup.find_all('a')[:10]
data = []
for tag in a_tags:
    data.append({
        'Tag': tag.name,
        'Text': tag.get_text(strip=True)or "No disponible",
        'Href': tag.get('href'),
        'Class': ' '.join(tag.get('class')) if tag.get('class') else "No disponible",
        'div id': tag.get('id') if tag.get('id') else "no disponible"
        
    })

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#   Tag                Text                            Href           Class  \
# 0   a           Translate    https://translate.google.com  goog-logo-link
# 1   a       No disponible                    /default.asp   No disponible
# 2   a                Home                               /        mainmenu
# 3   a  Legislation & Laws                   /legislation/        mainmenu
# 4   a              Senate                        /senate/        mainmenu
# 5   a               House                         /house/        mainmenu
# 6   a      My Legislation                 /mylegislation/        mainmenu
# 7   a            Site Map                    /sitemap.asp        mainmenu
# 8   a             Members             /senate/default.asp        sidemenu
# 9   a          Committees  /senate/committees/default.asp        sidemenu
#
#           div id
# 0  no disponible
# 1  no disponible
# 2  no disponible
# 3  no disponible
# 4  no disponible
# 5  no disponible
# 6  no disponible
# ...

# %%
pip install sqlalchemy psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("postgresql://user:postgres:5432/base2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 3
#       1 import pandas as pd
#       2 from sqlalchemy import create_engine
# ----> 3 engine = create_engine("postgresql://user:postgres:5432/base2")
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/sqlalchemy/engine/create.py:549, in create_engine(url, **kwargs)
#     546 kwargs.pop("empty_in_strategy", None)
# ...

# %%
df.to_sql("datos_scraping", engine, if_exists='replace', index=False)

print("Datos insertados exitosamente en la base de datos PostgreSQL.")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.local/lib/python3.9/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~/.local/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File ~/.local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...

# %%
df
# Out:
#   Tag                Text                            Href           Class  \
# 0   a           Translate    https://translate.google.com  goog-logo-link
# 1   a       No disponible                    /default.asp   No disponible
# 2   a                Home                               /        mainmenu
# 3   a  Legislation & Laws                   /legislation/        mainmenu
# 4   a              Senate                        /senate/        mainmenu
# 5   a               House                         /house/        mainmenu
# 6   a      My Legislation                 /mylegislation/        mainmenu
# 7   a            Site Map                    /sitemap.asp        mainmenu
# 8   a             Members             /senate/default.asp        sidemenu
# 9   a          Committees  /senate/committees/default.asp        sidemenu
#
#           div id
# 0  no disponible
# 1  no disponible
# 2  no disponible
# 3  no disponible
# 4  no disponible
# 5  no disponible
# 6  no disponible
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine("postgresql://postgres:postgres@localhost:5432/postgres")

# %%
df.to_sql("datos_trabajo", engine, if_exists='replace', index=False)
# Out:
# 10
